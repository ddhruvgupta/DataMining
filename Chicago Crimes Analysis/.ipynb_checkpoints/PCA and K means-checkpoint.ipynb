# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# %%
df = pd.read_csv("Classifier_inputs.csv")

# %%
df.head(1)
# Out:
#    Unnamed: 0  loc_desc  Arrest  Domestic  Beat  District  Ward  area  FBI  \
# 0           0        17       1         1  1022      10.0  24.0  29.0   10
#
#    Year  Longitude   Latitude
# 0  2016 -87.706819  41.864073

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'loc_desc', 'Arrest', 'Domestic', 'Beat', 'District',
#        'Ward', 'area', 'FBI', 'Year', 'Longitude', 'Latitude'],
#       dtype='object')

# %%
features = ['loc_desc', 'Arrest', 'Domestic', 'Beat', 'District','Ward', 'area', 'FBI', 'Year', 'Longitude', 'Latitude']

# %%
X = pd.read_csv("targets.csv")
X.head(1)
# Out:
#    Unnamed: 0 Primary Type
# 0           0      BATTERY

# %%
X['Primary Type'].value_counts()
# Out:
# THEFT                                322428
# BATTERY                              258945
# CRIMINAL DAMAGE                      152814
# NARCOTICS                            131182
# ASSAULT                               89512
# OTHER OFFENSE                         85362
# BURGLARY                              81673
# DECEPTIVE PRACTICE                    68342
# MOTOR VEHICLE THEFT                   59856
# ROBBERY                               56096
# CRIMINAL TRESPASS                     36429
# WEAPONS VIOLATION                     16983
# PUBLIC PEACE VIOLATION                13015
# OFFENSE INVOLVING CHILDREN            10591
# PROSTITUTION                           7567
# CRIM SEXUAL ASSAULT                    6298
# INTERFERENCE WITH PUBLIC OFFICER       6136
# SEX OFFENSE                            4491
# HOMICIDE                               2590
# GAMBLING                               2211
# ARSON                                  2175
# LIQUOR LAW VIOLATION                   1928
# KIDNAPPING                             1075
# STALKING                                774
# INTIMIDATION                            643
# OBSCENITY                               169
# CONCEALED CARRY LICENSE VIOLATION        84
# NON-CRIMINAL                             80
# PUBLIC INDECENCY                         61
# NON - CRIMINAL                           38
# OTHER NARCOTIC VIOLATION                 30
# HUMAN TRAFFICKING                        20
# NON-CRIMINAL (SUBJECT SPECIFIED)          4
# Name: Primary Type, dtype: int64

# %%
X['Primary Type'].nunique()
# Out:
# 33

# %%
pca = PCA(n_components=3)
principalComponents = pca.fit_transform(df[features])

principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2', 'principal component 3'])

principalDf
# Out:
#          principal component 1  principal component 2  principal component 3
# 0                  -128.397202              76.843408              -9.794971
# 1                  -837.443230             -15.836218             -10.271056
# 2                   373.868657             -30.718115              -8.885444
# 3                   381.740469             -26.700924              -6.814989
# 4                   372.730820             -14.688227              -6.848847
# ...                        ...                    ...                    ...
# 1419597            -116.361137              76.874128              -9.511523
# 1419598            -420.060197              76.062105              25.560937
# 1419599            -325.950605             -27.770507              23.239124
# 1419600            -727.688367             -27.915331              -1.608872
# 1419601            -828.059327              -8.368879              19.659260
#
# [1419602 rows x 3 columns]

# %%
variance = pca.explained_variance_ratio_ #calculate variance ratios
print(variance)

var=np.round(variance, decimals=3)*100


plt.figure(figsize = (20,5))

plt.style.use('ggplot')
x_pos = [i for i, _ in enumerate(principalDf.columns)]

plt.bar(x_pos, var, color='green')
plt.ylabel('% Variance Explained')
plt.xlabel('# of Features')
plt.title('PCA Analysis')

plt.xticks(x_pos, principalDf.columns)

plt.show()
# Out:
# [9.95648109e-01 3.32653489e-03 7.50670815e-04]

# %%
finalDf = pd.concat([principalDf, X[['Primary Type']]], axis = 1)
finalDf.head()
# Out:
#    principal component 1  principal component 2  principal component 3  \
# 0            -128.397202              76.843408              -9.794971
# 1            -837.443230             -15.836218             -10.271056
# 2             373.868657             -30.718115              -8.885444
# 3             381.740469             -26.700924              -6.814989
# 4             372.730820             -14.688227              -6.848847
#
#              Primary Type
# 0                 BATTERY
# 1                 BATTERY
# 2  PUBLIC PEACE VIOLATION
# 3                 BATTERY
# 4                   THEFT

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
finalDf['Primary Type'] = LE.fit_transform(finalDf['Primary Type'])
finalDf.head()
# Out:
#    principal component 1  principal component 2  principal component 3  \
# 0            -128.397202              76.843408              -9.794971
# 1            -837.443230             -15.836218             -10.271056
# 2             373.868657             -30.718115              -8.885444
# 3             381.740469             -26.700924              -6.814989
# 4             372.730820             -14.688227              -6.848847
#
#    Primary Type
# 0             2
# 1             2
# 2            27
# 3             2
# 4            31

# %%
# define the colormap
cmap = plt.cm.jet
# extract all colors from the .jet map
cmaplist = [cmap(i) for i in range(cmap.N)]
# create the new map
cmap = cmap.from_list('Custom cmap', cmaplist, cmap.N)

N = 33
# define the bins and normalize
bounds = np.linspace(0,N,N+1)
norm = mpl.colors.BoundaryNorm(bounds, cmap.N)

# %%
cmap

# %%
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

viridis = cm.get_cmap('viridis', 12)

fig = plt.figure(figsize = (8,8))
ax = Axes3D(fig)

ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_zlabel('Principal Component 3', fontsize = 15)

ax.set_title('3 component PCA', fontsize = 20)

# LABEL_COLOR_MAP = {0 : 'r',1 : 'b', 2 : 'g'}
LABEL_COLOR_MAP = viridis(np.linspace(0, 1, 35))

label_color = [LABEL_COLOR_MAP[l] for l in finalDf['Primary Type']]

ax.scatter(finalDf['principal component 1'], finalDf['principal component 2'], finalDf['principal component 3'],
           c=label_color)

# %%
kmean = KMeans(n_clusters=33).fit(df[features])
cl = kmean.cluster_centers_

fig = plt.figure(figsize = (8,8))
ax = Axes3D(fig)
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_zlabel('Principal Component 3', fontsize = 15)
ax.set_title('33 cluster k-means', fontsize = 20)


# LABEL_COLOR_MAP = {0 : 'r', 1 : 'b', 2 :'g'}


label_color = [LABEL_COLOR_MAP[l] for l in kmean.labels_]
ax.scatter(finalDf['principal component 1'], finalDf['principal component 2'], finalDf['principal component 3']
             , c=label_color  )

# %%
cl
# Out:
# array([[ 9.32662221e+01,  1.94728213e-01,  5.82513558e-02,
#          1.92301045e+03,  1.89996847e+01,  4.29923540e+01,
#          5.25564384e+00,  1.07805682e+01,  2.01385145e+03,
#         -8.76594513e+01,  4.19475473e+01],
#        [ 1.14820158e+02,  2.49209808e-01,  1.64390708e-01,
#          4.21445991e+02,  4.00098199e+00,  8.16795041e+00,
#          4.71177463e+01,  1.22153466e+01,  2.01382034e+03,
#         -8.75640764e+01,  4.17328384e+01],
#        [ 2.04506849e+01,  2.99511620e-01,  3.45318289e-01,
#          1.08291672e+03,  1.06082856e+01,  2.42759908e+01,
#          3.62669997e+01,  1.31265893e+01,  2.01381705e+03,
#         -8.77968559e+01,  4.19660402e+01],
#        [ 2.16396183e+01,  2.45619238e-01,  3.23745080e-01,
#          6.65076643e+02,  6.42448914e+00,  1.38272497e+01,
#          6.18562571e+01,  1.13453119e+01,  2.01384450e+03,
#         -8.76381752e+01,  4.17589512e+01],
#        [ 2.63129320e+01,  2.03885732e-01,  1.96052834e-01,
#          1.41294494e+03,  1.38024881e+01,  2.02706957e+01,
#          2.29520043e+01,  1.04864076e+01,  2.01362671e+03,
#         -8.76934050e+01,  4.19131799e+01],
#        [ 2.27560255e+01,  2.77621369e-01,  2.67664630e-01,
#          8.71351439e+02,  8.47679050e+00,  1.45679805e+01,
#          6.02098125e+01,  1.14253245e+01,  2.01381968e+03,
#         -8.76901963e+01,  4.17958236e+01],
#        [ 2.24375607e+01,  2.13437669e-01,  3.07285483e-01,
#          4.21944954e+02,  4.00604425e+00,  8.08586077e+00,
#          4.60766325e+01,  1.12989746e+01,  2.01386945e+03,
#         -8.75631225e+01,  4.17385377e+01],
#        [ 2.31532132e+01,  1.86935112e-01,  3.01377548e-01,
#          2.22510939e+02,  2.00000000e+00,  5.94433709e+00,
#          3.86321760e+01,  1.12010223e+01,  2.01392046e+03,
#         -8.76124286e+01,  4.18085613e+01],
#        [ 3.87930843e+01,  2.88303313e-01,  5.10896153e-02,
#          1.82654481e+03,  1.79991661e+01,  3.97522237e+01,
#          7.84322882e+00,  1.03737492e+01,  2.01387141e+03,
#         -8.76337274e+01,  4.19010180e+01]])

# %%
kmean.labels_
# Out:
# array([ 2, 20,  4, ..., 18,  1, 20])

# %%
kmean
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=33, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
cluster_map = pd.DataFrame()
cluster_map['data_index'] = df.index.values
cluster_map['primary_type'] = finalDf['Primary Type']
cluster_map['cluster'] = kmean.labels_
cluster_map.head()

# %%
# Out:
#    data_index  primary_type  cluster
# 0           0             2        2
# 1           1             2       20
# 2           2            27        4
# 3           3             2        4
# 4           4            31        4

# %%
features = ['primary_type', 'cluster']
temp = (cluster_map[features]).groupby(features).aggregate({"primary_type":['count']})
# temp = temp.reset_index()
temp.head()
# Out:
#                      primary_type
#                             count
# primary_type cluster
# 0            0                 55
#              1                101
#              2                 51
#              3                182
#              4                 82

# %%
kmean = KMeans(n_clusters=10).fit(df[features])
cl = kmean.cluster_centers_

fig = plt.figure(figsize = (8,8))
ax = Axes3D(fig)
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_zlabel('Principal Component 3', fontsize = 15)
ax.set_title('33 cluster k-means', fontsize = 20)


# LABEL_COLOR_MAP = {0 : 'r', 1 : 'b', 2 :'g'}


label_color = [LABEL_COLOR_MAP[l] for l in kmean.labels_]
ax.scatter(finalDf['principal component 1'], finalDf['principal component 2'], finalDf['principal component 3']
             , c=label_color  )
# Out:
#   File "<ipython-input-37-2af4b2961b21>", line 1
#     kmean = KMeans(n_clusters=10fit(df[features])
#                                   ^
# SyntaxError: invalid syntax
